# %% [markdown]
# <a href="https://colab.research.google.com/github/georgekuttytom2004-eng/Python_basics/blob/main/miscelleneous.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class employee:

  def __init__(self):
    self.name = "rahul"
    self.salary = 50000
    self.__password = "12345"

  def show_details(self):
    print(self.name)
    print(self._salary)
    print(self.__password)

emp = employee()
print(emp.name)
print(emp.__password)
# Out:
# rahul
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1091/988621536.py in <cell line: 0>()
#      13 emp = employee()
#      14 print(emp.name)
# ---> 15 print(emp.__password)
#
# AttributeError: 'employee' object has no attribute '__password'

# %%
class employee:
  def __init__(self):
      self.name = "anu"
      self._salary = 50000
      self.__password = "12345"

  def show_parent(self):
    print("name:",self.name)
    print("salary:",self.salary)
    print("password:",self.__password)

class manager(employee):
  def show_manager(self):
    print("name:", self.name)
    print("salary:", self._salary)



manager = manager()
manager.show_manager()
# Out:
# name: anu
# salary: 50000
