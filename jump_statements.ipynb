# %% [markdown]
# <a href="https://colab.research.google.com/github/georgekuttytom2004-eng/Python_basics/blob/main/jump_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,6):
 if (i==4):
  continue;
 print(i)
# Out:
# 1
# 2
# 3
# 5
